# %% [markdown]
# ## 基本水球图

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid

c = (
    Liquid()
    .add("lq", [0.6, 0.7])
    .set_global_opts(title_opts=opts.TitleOpts(title="基本形状"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="e4ccc6bee24c4cb0b16f0f8975d172ba" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_e4ccc6bee24c4cb0b16f0f8975d172ba = echarts.init(
#                     document.getElementById('e4ccc6bee24c4cb0b16f0f8975d172ba'), 'white', {renderer: 'canvas'});
#                 var option_e4ccc6bee24c4cb0b16f0f8975d172ba = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u57fa\u672c\u5f62\u72b6",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e4ccc6bee24c4cb0b16f0f8975d172ba.setOption(option_e4ccc6bee24c4cb0b16f0f8975d172ba);
#         });
#     </script>

# %% [markdown]
# ## 改变水球图的形状和颜色
# 通过设置以下参数，可以变换水球的形状和颜色
#
# - color：改变水的颜色，注意，颜色是列表形式
# - shape：改变形状，水球外形，有' circle', 'rect', 'roundRect', 'triangle'

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid
from pyecharts.globals import SymbolType

c = (
    Liquid()
    .add("lq", [0.3, 0.7], shape=SymbolType.TRIANGLE,
         color=['#4B0082'])
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-Shape-rect"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="5c9c2eceba4d48918d89dc3ae6e55d5f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_5c9c2eceba4d48918d89dc3ae6e55d5f = echarts.init(
#                     document.getElementById('5c9c2eceba4d48918d89dc3ae6e55d5f'), 'white', {renderer: 'canvas'});
#                 var option_5c9c2eceba4d48918d89dc3ae6e55d5f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.3,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#4B0082"
#             ],
#             "shape": "triangle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid-Shape-rect",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5c9c2eceba4d48918d89dc3ae6e55d5f.setOption(option_5c9c2eceba4d48918d89dc3ae6e55d5f);
#         });
#     </script>

# %% [markdown]
# ## 不显示外边框，多波浪
#
# - is_outline_show：控制外边框

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid
from pyecharts.globals import SymbolType

c = (
    Liquid()
    .add("lq",[0.67, 0.30, 0.15], is_outline_show=False)
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-Shape-rect"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="12c0112a4abb42f4a764a1435770d5ca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_12c0112a4abb42f4a764a1435770d5ca = echarts.init(
#                     document.getElementById('12c0112a4abb42f4a764a1435770d5ca'), 'white', {renderer: 'canvas'});
#                 var option_12c0112a4abb42f4a764a1435770d5ca = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.67,
#                 0.3,
#                 0.15
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": false,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid-Shape-rect",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_12c0112a4abb42f4a764a1435770d5ca.setOption(option_12c0112a4abb42f4a764a1435770d5ca);
#         });
#     </script>

# %% [markdown]
# ## 多个水球图显示
#
# 将水球按一定规则摆放在一起，用来展示多个数据指标，将会非常美观

# %%
from pyecharts import options as opts
from pyecharts.charts import Grid, Liquid
from pyecharts.commons.utils import JsCode

l1 = (
    Liquid()
    .add("lq", [0.6, 0.7], 
         center=["13%", "60%"],
         color=['#3CB371'],
         label_opts=opts.LabelOpts(
         font_size=20,
         formatter=JsCode(
            """function (param) {
                    return ('第一季度：'+Math.floor(param.value * 10000) / 100) + '%';
                }"""
        ),
        position="inside",
    ),)
    .set_global_opts(title_opts=opts.TitleOpts(title="多个 Liquid 显示"))
)

l2 = Liquid().add(
    "lq",
    [0.5554],
    center=["38%", "60%"],
    color=['#87CEEB'],
    label_opts=opts.LabelOpts(
        font_size=20,
        formatter=JsCode(
            """function (param) {
                    return ('第二季度：'+Math.floor(param.value * 10000) / 100) + '%';
                }"""
        ),
        position="inside",
    ),
)

l3 = (
    Liquid()
    .add("lq", [0.63, 0.7], 
         center=["63%", "60%"],
         color=['#FAFAD2'],
         label_opts=opts.LabelOpts(
         font_size=20,
         formatter=JsCode(
            """function (param) {
                    return ('第三季度：'+Math.floor(param.value * 10000) / 100) + '%';
                }"""
        ),
        position="inside",
    ),)
    .set_global_opts(title_opts=opts.TitleOpts(title="多个 Liquid 显示"))
)

l4 = Liquid().add(
    "lq",
    [0.4954],
    center=["88%", "60%"],
    color=['#C0C0C0'],
    label_opts=opts.LabelOpts(
        font_size=20,
        formatter=JsCode(
            """function (param) {
                    return ('第四季度：'+Math.floor(param.value * 10000) / 100) + '%';
                }"""
        ),
        position="inside",
    ),
)
grid = Grid().add(l1, grid_opts=opts.GridOpts()).add(l2, grid_opts=opts.GridOpts()).add(l3, grid_opts=opts.GridOpts()).add(l4, grid_opts=opts.GridOpts())
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="3f62ecaf616d4bdfb37a4893fe22269d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_3f62ecaf616d4bdfb37a4893fe22269d = echarts.init(
#                     document.getElementById('3f62ecaf616d4bdfb37a4893fe22269d'), 'white', {renderer: 'canvas'});
#                 var option_3f62ecaf616d4bdfb37a4893fe22269d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#3CB371"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 20,
#                 "formatter": function (param) {                    return ('\u7b2c\u4e00\u5b63\u5ea6\uff1a'+Math.floor(param.value * 10000) / 100) + '%';                }
#             },
#             "center": [
#                 "13%",
#                 "60%"
#             ],
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         },
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.5554
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#87CEEB"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 20,
#                 "formatter": function (param) {                    return ('\u7b2c\u4e8c\u5b63\u5ea6\uff1a'+Math.floor(param.value * 10000) / 100) + '%';                }
#             },
#             "center": [
#                 "38%",
#                 "60%"
#             ],
#             "xAxisIndex": 1,
#             "yAxisIndex": 1
#         },
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.63,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#FAFAD2"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 20,
#                 "formatter": function (param) {                    return ('\u7b2c\u4e09\u5b63\u5ea6\uff1a'+Math.floor(param.value * 10000) / 100) + '%';                }
#             },
#             "center": [
#                 "63%",
#                 "60%"
#             ],
#             "xAxisIndex": 2,
#             "yAxisIndex": 2
#         },
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.4954
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#C0C0C0"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 20,
#                 "formatter": function (param) {                    return ('\u7b2c\u56db\u5b63\u5ea6\uff1a'+Math.floor(param.value * 10000) / 100) + '%';                }
#             },
#             "center": [
#                 "88%",
#                 "60%"
#             ],
#             "xAxisIndex": 3,
#             "yAxisIndex": 3
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [],
#             "selected": {}
#         },
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u591a\u4e2a Liquid \u663e\u793a",
#             "padding": 5,
#             "itemGap": 10
#         },
#         {
#             "padding": 5,
#             "itemGap": 10
#         },
#         {
#             "text": "\u591a\u4e2a Liquid \u663e\u793a",
#             "padding": 5,
#             "itemGap": 10
#         },
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "grid": [
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         },
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         },
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         },
#         {
#             "show": false,
#             "zlevel": 0,
#             "z": 2,
#             "containLabel": false,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1
#         }
#     ]
# };
#                 chart_3f62ecaf616d4bdfb37a4893fe22269d.setOption(option_3f62ecaf616d4bdfb37a4893fe22269d);
#         });
#     </script>
