# %% [markdown]
# # boss_analysis + pyecharts

# %% [markdown]
# ## 1. 数据获取
#
# BOSS直聘上有这么一个接口，可以很好的获取当前不同岗位，不同城市的薪资水平
#
# https://www.zhipin.com/wapi/zpboss/h5/marketpay/statistics.json

# %% [markdown]
# 参数
# - java:position=100101
# - 产品经理:position=110101
# - python:position=100109

# %%
import requests
headers = {'accept': 'application/json, text/plain, */*',
          'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_0_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36'}

# %%
querystring = {"positionId":"100101","industryId":"0","cityId":"0","companySize":"0","financingStage":"0","experienceCode":"0"}

# %%
job_statics_url = 'https://www.zhipin.com/wapi/zpboss/h5/marketpay/statistics.json'

# %%
job_statics_data = requests.get(job_statics_url, params=querystring, headers=headers)

# %%
job_statics_data.json()
# Out:
# {'code': 0,
#  'message': 'Success',
#  'zpData': {'positionId': 100101,
#   'industryId': 0,
#   'cityId': 0,
#   'companySize': 0,
#   'financingStage': 0,
#   'experienceCode': 0,
#   'sampleCount': 18475470,
#   'sampleInsufficient': False,
#   'salaryByMonth': [{'year': '2020年',
#     'showYear': True,
#     'month': '2月',
#     'monthAveSalary': 8852,
#     'title': 'Feb',
#     'grow': False,
#     'percent': 2.33,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '3月',
#     'monthAveSalary': 8433,
#     'title': 'Mar',
#     'grow': False,
#     'percent': 4.73,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '4月',
#     'monthAveSalary': 8338,
#     'title': 'Apr',
#     'grow': False,
#     'percent': 1.13,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '5月',
#     'monthAveSalary': 8253,
#     'title': 'May',
#     'grow': False,
#     'percent': 1.02,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '6月',
#     'monthAveSalary': 8311,
#     'title': 'Jun',
#     'grow': True,
#     'percent': 0.7,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '7月',
#     'monthAveSalary': 8266,
#     'title': 'Jul',
#     'grow': False,
#     'percent': 0.54,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '8月',
#     'monthAveSalary': 8443,
#     'title': 'Aug',
#     'grow': True,
#     'percent': 2.14,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '9月',
#     'monthAveSalary': 8480,
#     'title': 'Sept',
#     'grow': True,
#     'percent': 0.44,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '10月',
#     'monthAveSalary': 8497,
#     'title': 'Oct',
#     'grow': True,
#     'percent': 0.2,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '11月',
#     'monthAveSalary': 8627,
#     'title': 'Nov',
#     'grow': True,
#     'percent': 1.53,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2020年',
#     'showYear': False,
#     'month': '12月',
#     'monthAveSalary': 8765,
#     'title': 'Dec',
#     'grow': True,
#     'percent': 1.6,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0},
#    {'year': '2021年',
#     'showYear': True,
#     'month': '1月',
#     'monthAveSalary': 9104,
#     'title': 'Jan',
#     'grow': True,
#     'percent': 3.87,
#     'effectiveJobCount': 0,
#     'effectiveJobGrowthRatio': 0.0,
#     'effectiveJobGrowthOneMonth': 0,
#     'effectiveJobGrowthTwoMonth': 0}],
#   'salaryByAge': [{'ageRange': '24岁以下',
#     'percent': 34,
#     'people': 6205455,
#     'percentDecimal': 0.335875,
#     'index': 0},
#    {'ageRange': '25岁-29岁',
#     'percent': 52,
#     'people': 9612491,
#     'percentDecimal': 0.520284,
#     'index': 1},
#    {'ageRange': '30岁-34岁',
#     'percent': 12,
#     'people': 2213612,
#     'percentDecimal': 0.119814,
#     'index': 2},
#    {'ageRange': '35岁-39岁',
#     'percent': 2,
#     'people': 362400,
#     'percentDecimal': 0.019615,
#     'index': 3},
#    {'ageRange': '40岁-44岁',
#     'percent': 0,
#     'people': 66849,
#     'percentDecimal': 0.003618,
#     'index': 4},
#    {'ageRange': '45岁以上',
#     'percent': 0,
#     'people': 14663,
#     'percentDecimal': 0.000794,
#     'index': 5}],
#   'salaryByWorkExp': [{'percent': 1,
#     'aveSalary': 5363,
#     'workExp': '1年以内',
#     'percentDecimal': 0.013944,
#     'index': 0},
#    {'percent': 30,
#     'aveSalary': 7041,
#     'workExp': '1-3年',
#     'percentDecimal': 0.300505,
#     'index': 1},
#    {'percent': 53,
#     'aveSalary': 9408,
#     'workExp': '3-5年',
#     'percentDecimal': 0.526062,
#     'index': 2},
#    {'percent': 16,
#     'aveSalary': 11937,
#     'workExp': '5-10年',
#     'percentDecimal': 0.157183,
#     'index': 3},
#    {'percent': 0,
#     'aveSalary': 15118,
#     'workExp': '10年以上',
#     'percentDecimal': 0.002307,
#     'index': 4}],
#   'salaryByDistributed': [{'salaryRange': '<7.99',
#     'percent': 22,
#     'people': 0,
#     'percentDecimal': 0.224493,
#     'index': 0},
#    {'salaryRange': '7.99-11.15',
#     'percent': 28,
#     'people': 0,
#     'percentDecimal': 0.277825,
#     'index': 1},
#    {'salaryRange': '11.15-14.31',
#     'percent': 22,
#     'people': 0,
#     'percentDecimal': 0.220465,
#     'index': 2},
#    {'salaryRange': '14.31-17.47',
#     'percent': 13,
#     'people': 0,
#     'percentDecimal': 0.130994,
#     'index': 3},
#    {'salaryRange': '>17.47',
#     'percent': 15,
#     'people': 0,
#     'percentDecimal': 0.145739,
#     'index': 4}],
#   'salaryByPoints': [{'name': '10分位',
#     'title': '低端',
#     'salary': 64054,
#     'point': 10},
#    {'name': '25分位', 'title': '中低端', 'salary': 83014, 'point': 25},
#    {'name': '50分位', 'title': '中端', 'salary': 110130, 'point': 50},
#    {'name': '75分位', 'title': '中高端', 'salary': 146312, 'point': 75},
#    {'name': '90分位', 'title': '高端', 'salary': 190487, 'point': 90}],
#   'salaryByCity': [{'provinceId': 101010000,
#     'provinceAveMonthSalary': 15244,
#     'provinceName': '北京',
#     'cityList': [{'cityId': 101010100,
#       'cityName': '北京',
#       'cityAveMonthSalary': 15244}]},
#    {'provinceId': 101020000,
#     'provinceAveMonthSalary': 14419,
#     'provinceName': '上海',
#     'cityList': [{'cityId': 101020100,
#       'cityName': '上海',
#       'cityAveMonthSalary': 14419}]},
#    {'provinceId': 101030000,
#     'provinceAveMonthSalary': 8950,
#     'provinceName': '天津',
#     'cityList': [{'cityId': 101030100,
#       'cityName': '天津',
#       'cityAveMonthSalary': 8950}]},
#    {'provinceId': 101040000,
#     'provinceAveMonthSalary': 8629,
#     'provinceName': '重庆',
#     'cityList': [{'cityId': 101040100,
#       'cityName': '重庆',
#       'cityAveMonthSalary': 8629}]},
#    {'provinceId': 101050000,
#     'provinceAveMonthSalary': 6303,
#     'provinceName': '黑龙江',
#     'cityList': [{'cityId': 101050100,
#       'cityName': '哈尔滨',
#       'cityAveMonthSalary': 6303}]},
#    {'provinceId': 101060000,
#     'provinceAveMonthSalary': 6893,
#     'provinceName': '吉林',
#     'cityList': [{'cityId': 101060100,
#       'cityName': '长春',
#       'cityAveMonthSalary': 6893}]},
#    {'provinceId': 101070000,
#     'provinceAveMonthSalary': 7077,
#     'provinceName': '辽宁',
#     'cityList': [{'cityId': 101070100,
#       'cityName': '沈阳',
#       'cityAveMonthSalary': 6740},
#      {'cityId': 101070200, 'cityName': '大连', 'cityAveMonthSalary': 7414}]},
#    {'provinceId': 101090000,
#     'provinceAveMonthSalary': 7888,
#     'provinceName': '河北',
#     'cityList': [{'cityId': 101090100,
#       'cityName': '石家庄',
#       'cityAveMonthSalary': 6730},
#      {'cityId': 101090200, 'cityName': '保定', 'cityAveMonthSalary': 7320},
#      {'cityId': 101090600, 'cityName': '廊坊', 'cityAveMonthSalary': 9615}]},
#    {'provinceId': 101100000,
#     'provinceAveMonthSalary': 6755,
#     'provinceName': '山西',
#     'cityList': [{'cityId': 101100100,
#       'cityName': '太原',
#       'cityAveMonthSalary': 6755}]},
#    {'provinceId': 101110000,
#     'provinceAveMonthSalary': 9715,
#     'provinceName': '陕西',
#     'cityList': [{'cityId': 101110100,
#       'cityName': '西安',
#       'cityAveMonthSalary': 9715}]},
#    {'provinceId': 101120000,
#     'provinceAveMonthSalary': 7328,
#     'provinceName': '山东',
#     'cityList': [{'cityId': 101120100,
#       'cityName': '济南',
#       'cityAveMonthSalary': 7622},
#      {'cityId': 101120200, 'cityName': '青岛', 'cityAveMonthSalary': 8168},
#      {'cityId': 101120500, 'cityName': '烟台', 'cityAveMonthSalary': 6195}]},
#    {'provinceId': 101160000,
#     'provinceAveMonthSalary': 6830,
#     'provinceName': '甘肃',
#     'cityList': [{'cityId': 101160100,
#       'cityName': '兰州',
#       'cityAveMonthSalary': 6830}]},
#    {'provinceId': 101180000,
#     'provinceAveMonthSalary': 7923,
#     'provinceName': '河南',
#     'cityList': [{'cityId': 101180100,
#       'cityName': '郑州',
#       'cityAveMonthSalary': 7923}]},
#    {'provinceId': 101190000,
#     'provinceAveMonthSalary': 8393,
#     'provinceName': '江苏',
#     'cityList': [{'cityId': 101190100,
#       'cityName': '南京',
#       'cityAveMonthSalary': 11069},
#      {'cityId': 101190200, 'cityName': '无锡', 'cityAveMonthSalary': 8846},
#      {'cityId': 101190400, 'cityName': '苏州', 'cityAveMonthSalary': 9888},
#      {'cityId': 101190500, 'cityName': '南通', 'cityAveMonthSalary': 7635},
#      {'cityId': 101190600, 'cityName': '扬州', 'cityAveMonthSalary': 7373},
#      {'cityId': 101190800, 'cityName': '徐州', 'cityAveMonthSalary': 6225},
#      {'cityId': 101191100, 'cityName': '常州', 'cityAveMonthSalary': 7713}]},
#    {'provinceId': 101200000,
#     'provinceAveMonthSalary': 10076,
#     'provinceName': '湖北',
#     'cityList': [{'cityId': 101200100,
#       'cityName': '武汉',
#       'cityAveMonthSalary': 10076}]},
#    {'provinceId': 101210000,
#     'provinceAveMonthSalary': 8779,
#     'provinceName': '浙江',
#     'cityList': [{'cityId': 101210100,
#       'cityName': '杭州',
#       'cityAveMonthSalary': 13234},
#      {'cityId': 101210300, 'cityName': '嘉兴', 'cityAveMonthSalary': 7826},
#      {'cityId': 101210400, 'cityName': '宁波', 'cityAveMonthSalary': 8700},
#      {'cityId': 101210500, 'cityName': '绍兴', 'cityAveMonthSalary': 7663},
#      {'cityId': 101210600, 'cityName': '台州', 'cityAveMonthSalary': 8308},
#      {'cityId': 101210700, 'cityName': '温州', 'cityAveMonthSalary': 7180},
#      {'cityId': 101210900, 'cityName': '金华', 'cityAveMonthSalary': 8545}]},
#    {'provinceId': 101220000,
#     'provinceAveMonthSalary': 8644,
#     'provinceName': '安徽',
#     'cityList': [{'cityId': 101220100,
#       'cityName': '合肥',
#       'cityAveMonthSalary': 8644}]},
#    {'provinceId': 101230000,
#     'provinceAveMonthSalary': 6769,
#     'provinceName': '福建',
#     'cityList': [{'cityId': 101230100,
#       'cityName': '福州',
#       'cityAveMonthSalary': 7916},
#      {'cityId': 101230200, 'cityName': '厦门', 'cityAveMonthSalary': 9272},
#      {'cityId': 101230500, 'cityName': '泉州', 'cityAveMonthSalary': 6769}]},
#    {'provinceId': 101240000,
#     'provinceAveMonthSalary': 6937,
#     'provinceName': '江西',
#     'cityList': [{'cityId': 101240100,
#       'cityName': '南昌',
#       'cityAveMonthSalary': 7275}]},
#    {'provinceId': 101250000,
#     'provinceAveMonthSalary': 9067,
#     'provinceName': '湖南',
#     'cityList': [{'cityId': 101250100,
#       'cityName': '长沙',
#       'cityAveMonthSalary': 9067}]},
#    {'provinceId': 101260000,
#     'provinceAveMonthSalary': 7471,
#     'provinceName': '贵州',
#     'cityList': [{'cityId': 101260100,
#       'cityName': '贵阳',
#       'cityAveMonthSalary': 7471}]},
#    {'provinceId': 101270000,
#     'provinceAveMonthSalary': 9932,
#     'provinceName': '四川',
#     'cityList': [{'cityId': 101270100,
#       'cityName': '成都',
#       'cityAveMonthSalary': 9932}]},
#    {'provinceId': 101280000,
#     'provinceAveMonthSalary': 9604,
#     'provinceName': '广东',
#     'cityList': [{'cityId': 101280100,
#       'cityName': '广州',
#       'cityAveMonthSalary': 10392},
#      {'cityId': 101280300, 'cityName': '惠州', 'cityAveMonthSalary': 8041},
#      {'cityId': 101280600, 'cityName': '深圳', 'cityAveMonthSalary': 13482},
#      {'cityId': 101280700, 'cityName': '珠海', 'cityAveMonthSalary': 9161},
#      {'cityId': 101280800, 'cityName': '佛山', 'cityAveMonthSalary': 8937},
#      {'cityId': 101281600, 'cityName': '东莞', 'cityAveMonthSalary': 9693},
#      {'cityId': 101281700, 'cityName': '中山', 'cityAveMonthSalary': 7524}]},
#    {'provinceId': 101290000,
#     'provinceAveMonthSalary': 7478,
#     'provinceName': '云南',
#     'cityList': [{'cityId': 101290100,
#       'cityName': '昆明',
#       'cityAveMonthSalary': 7478}]},
#    {'provinceId': 101300000,
#     'provinceAveMonthSalary': 6695,
#     'provinceName': '广西',
#     'cityList': [{'cityId': 101300100,
#       'cityName': '南宁',
#       'cityAveMonthSalary': 6695}]},
#    {'provinceId': 101310000,
#     'provinceAveMonthSalary': 7666,
#     'provinceName': '海南',
#     'cityList': [{'cityId': 101310100,
#       'cityName': '海口',
#       'cityAveMonthSalary': 7666}]},
#    {'provinceId': 101080000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '内蒙古',
#     'cityList': None},
#    {'provinceId': 101130000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '新疆',
#     'cityList': None},
#    {'provinceId': 101150000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '青海',
#     'cityList': None},
#    {'provinceId': 101170000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '宁夏',
#     'cityList': None},
#    {'provinceId': 101340000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '台湾',
#     'cityList': None},
#    {'provinceId': 101140000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '西藏',
#     'cityList': None},
#    {'provinceId': 101320000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '香港',
#     'cityList': None},
#    {'provinceId': 101330000,
#     'provinceAveMonthSalary': 0,
#     'provinceName': '澳门',
#     'cityList': None}],
#   'lastUpdateTime': '2021年02月05日'}}

# %% [markdown]
# ## 2. 数据分析可视化
# ### 薪资分位值
#
# 在我们获取到的数据当中，就有分位值的数据，可以方便的获取

# %%
job_statics_data_json = job_statics_data.json()
job_statics_data_json['zpData']['salaryByPoints']
# Out:
# [{'name': '10分位', 'title': '低端', 'salary': 64054, 'point': 10},
#  {'name': '25分位', 'title': '中低端', 'salary': 83014, 'point': 25},
#  {'name': '50分位', 'title': '中端', 'salary': 110130, 'point': 50},
#  {'name': '75分位', 'title': '中高端', 'salary': 146312, 'point': 75},
#  {'name': '90分位', 'title': '高端', 'salary': 190487, 'point': 90}]

# %% [markdown]
# #### 薪资分位 - 折线图

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByPoints']:
    statics_x.append(i['name'] + '\n' + i['title'])
    statics_y.append(i['salary'])

# %%
import pyecharts.options as opts
from pyecharts.charts import Line, Bar, Pie, Calendar, WordCloud
from pyecharts.commons.utils import JsCode
from pyecharts.globals import SymbolType
import datetime
import random

# %%
x_data = statics_x
y_data = statics_y

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c_line = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="薪资",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="收入分位",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

# %%
c_line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="821c1ac565604bb4af28c690c7fdfc14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_821c1ac565604bb4af28c690c7fdfc14 = echarts.init(
#                     document.getElementById('821c1ac565604bb4af28c690c7fdfc14'), 'white', {renderer: 'canvas'});
#                 var option_821c1ac565604bb4af28c690c7fdfc14 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u85aa\u8d44",
#             "connectNulls": false,
#             "symbol": "circle",
#             "symbolSize": 6,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "10\u5206\u4f4d\n\u4f4e\u7aef",
#                     64054
#                 ],
#                 [
#                     "25\u5206\u4f4d\n\u4e2d\u4f4e\u7aef",
#                     83014
#                 ],
#                 [
#                     "50\u5206\u4f4d\n\u4e2d\u7aef",
#                     110130
#                 ],
#                 [
#                     "75\u5206\u4f4d\n\u4e2d\u9ad8\u7aef",
#                     146312
#                 ],
#                 [
#                     "90\u5206\u4f4d\n\u9ad8\u7aef",
#                     190487
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "white",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#fff"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "color": "red",
#                 "borderColor": "#fff",
#                 "borderWidth": 3
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u85aa\u8d44": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "margin": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "data": [
#                 "10\u5206\u4f4d\n\u4f4e\u7aef",
#                 "25\u5206\u4f4d\n\u4e2d\u4f4e\u7aef",
#                 "50\u5206\u4f4d\n\u4e2d\u7aef",
#                 "75\u5206\u4f4d\n\u4e2d\u9ad8\u7aef",
#                 "90\u5206\u4f4d\n\u9ad8\u7aef"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#fff"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 15,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "margin": 20
#             },
#             "inverse": false,
#             "position": "right",
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6536\u5165\u5206\u4f4d",

# %% [markdown]
# #### 薪资分布 - 横向柱形图

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByDistributed']:
    statics_y.append(i['percent'])
    statics_x.append(i['salaryRange'])

# %%
print(statics_x)
print(statics_y)
# Out:
# ['<7.99', '7.99-11.15', '11.15-14.31', '14.31-17.47', '>17.47']
# [22, 28, 22, 13, 15]

# %%
def bar_chart(x, y) -> Bar:
    background_color_js = (
        "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
        "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
    )
    c = (
        Bar(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        #Bar()
        .add_xaxis(x)
        # .add_xaxis(searchcount.index.tolist()[:10])
        .reversal_axis()
        .add_yaxis("", y, 
                   label_opts=opts.LabelOpts(position='inside', formatter="{c}%"),
                  color='plum', category_gap="60%"
                  )
        .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30, formatter="{value}%"),
                                                 axisline_opts=opts.AxisLineOpts(is_show=False),),
                        yaxis_opts=opts.AxisOpts(
                            axislabel_opts=opts.LabelOpts(is_show=True),
                        axisline_opts=opts.AxisLineOpts(is_show=False),
                        axistick_opts=opts.AxisTickOpts(
                        is_show=True,
                        length=25,
                        linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
                    ),)
                        )
        .set_series_opts(
            itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(255,100,97,.5)'
                }, {
                    offset: 1,
                    color: 'rgba(221,160,221)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }}
        )
    )
    return c

# %%
bar_chart(statics_x, statics_y).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="321d914966d544b586a62d53d3f33612" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_321d914966d544b586a62d53d3f33612 = echarts.init(
#                     document.getElementById('321d914966d544b586a62d53d3f33612'), 'white', {renderer: 'canvas'});
#                 var option_321d914966d544b586a62d53d3f33612 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "plum",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 22,
#                 28,
#                 22,
#                 13,
#                 15
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "60%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "formatter": "{c}%"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(255,100,97,.5)'                }, {                    offset: 1,                    color: 'rgba(221,160,221)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8,
#                 "formatter": "{value}%"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "<7.99",
#                 "7.99-11.15",
#                 "11.15-14.31",
#                 "14.31-17.47",
#                 ">17.47"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_321d914966d544b586a62d53d3f33612.setOption(option_321d914966d544b586a62d53d3f33612);
#         });
#     </script>

# %% [markdown]
# #### 薪资与工作经验 - 饼状玫瑰图

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByWorkExp']:
    statics_y.append(i['percent'])
    statics_x.append(i['workExp'] + ':' + str(i['aveSalary']))
statics_y
# Out:
# [1, 30, 53, 16, 0]

# %%
list(zip(statics_x, statics_y))
# Out:
# [('1年以内:5363', 1),
#  ('1-3年:7041', 30),
#  ('3-5年:9408', 53),
#  ('5-10年:11937', 16),
#  ('10年以上:15118', 0)]

# %%
def pie_rosetype(data) -> Pie:
    background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
    c = (
        Pie(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        .add(
            "",
            list(data),
            radius=["30%", "75%"],
            center=["45%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(formatter="{b}: {c}"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title=""),
                        )
    )
    return c

# %%
pie_rosetype(zip(statics_x, statics_y)).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="027abbe465184613a6eec9af8e2c50f6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_027abbe465184613a6eec9af8e2c50f6 = echarts.init(
#                     document.getElementById('027abbe465184613a6eec9af8e2c50f6'), 'white', {renderer: 'canvas'});
#                 var option_027abbe465184613a6eec9af8e2c50f6 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\u5e74\u4ee5\u5185:5363",
#                     "value": 1
#                 },
#                 {
#                     "name": "1-3\u5e74:7041",
#                     "value": 30
#                 },
#                 {
#                     "name": "3-5\u5e74:9408",
#                     "value": 53
#                 },
#                 {
#                     "name": "5-10\u5e74:11937",
#                     "value": 16
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a:15118",
#                     "value": 0
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "45%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\u5e74\u4ee5\u5185:5363",
#                 "1-3\u5e74:7041",
#                 "3-5\u5e74:9408",
#                 "5-10\u5e74:11937",
#                 "10\u5e74\u4ee5\u4e0a:15118"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_027abbe465184613a6eec9af8e2c50f6.setOption(option_027abbe465184613a6eec9af8e2c50f6);
#         });
#     </script>

# %% [markdown]
# #### 薪资与工作经验 - 饼图

# %%
background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
c = (
    Pie(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add(
        "",
        list(zip(statics_x, statics_y)),
        radius=["40%", "55%"],
        label_opts=opts.LabelOpts(
            position="outside",
            formatter="{a|job}{abg|}\n{hr|}\n {b|{b}: }{per|{d}%}  ",
            background_color="#eee",
            border_color="#aaa",
            border_width=1,
            border_radius=4,
            rich={
                "a": {"color": "#999", "lineHeight": 22, "align": "center"},
                "abg": {
                    "backgroundColor": "#e3e3e3",
                    "width": "100%",
                    "align": "right",
                    "height": 22,
                    "borderRadius": [4, 4, 0, 0],
                },
                "hr": {
                    "borderColor": "#aaa",
                    "width": "100%",
                    "borderWidth": 0.5,
                    "height": 0,
                },
                "b": {"fontSize": 16, "lineHeight": 33},
                "per": {
                    "color": "#eee",
                    "backgroundColor": "#334455",
                    "padding": [2, 4],
                    "borderRadius": 2,
                },
            },
        ),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3726fd638060478b9b6e452b7a741a89" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3726fd638060478b9b6e452b7a741a89 = echarts.init(
#                     document.getElementById('3726fd638060478b9b6e452b7a741a89'), 'white', {renderer: 'canvas'});
#                 var option_3726fd638060478b9b6e452b7a741a89 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1\u5e74\u4ee5\u5185:5363",
#                     "value": 1
#                 },
#                 {
#                     "name": "1-3\u5e74:7041",
#                     "value": 30
#                 },
#                 {
#                     "name": "3-5\u5e74:9408",
#                     "value": 53
#                 },
#                 {
#                     "name": "5-10\u5e74:11937",
#                     "value": 16
#                 },
#                 {
#                     "name": "10\u5e74\u4ee5\u4e0a:15118",
#                     "value": 0
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "55%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "outside",
#                 "margin": 8,
#                 "formatter": "{a|job}{abg|}\n{hr|}\n {b|{b}: }{per|{d}%}  ",
#                 "backgroundColor": "#eee",
#                 "borderColor": "#aaa",
#                 "borderWidth": 1,
#                 "borderRadius": 4,
#                 "rich": {
#                     "a": {
#                         "color": "#999",
#                         "lineHeight": 22,
#                         "align": "center"
#                     },
#                     "abg": {
#                         "backgroundColor": "#e3e3e3",
#                         "width": "100%",
#                         "align": "right",
#                         "height": 22,
#                         "borderRadius": [
#                             4,
#                             4,
#                             0,
#                             0
#                         ]
#                     },
#                     "hr": {
#                         "borderColor": "#aaa",
#                         "width": "100%",
#                         "borderWidth": 0.5,
#                         "height": 0
#                     },
#                     "b": {
#                         "fontSize": 16,
#                         "lineHeight": 33
#                     },
#                     "per": {
#                         "color": "#eee",
#                         "backgroundColor": "#334455",
#                         "padding": [
#                             2,
#                             4
#                         ],
#                         "borderRadius": 2
#                     }
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1\u5e74\u4ee5\u5185:5363",
#                 "1-3\u5e74:7041",
#                 "3-5\u5e74:9408",
#                 "5-10\u5e74:11937",
#                 "10\u5e74\u4ee5\u4e0a:15118"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3726fd638060478b9b6e452b7a741a89.setOption(option_3726fd638060478b9b6e452b7a741a89);
#         });
#     </script>

# %% [markdown]
# #### 人数与年龄 - 柱状图

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByAge']:
    statics_x.append(i['ageRange'])
    statics_y.append(i['people'])
print(statics_x)
print(statics_y)
# Out:
# ['24岁以下', '25岁-29岁', '30岁-34岁', '35岁-39岁', '40岁-44岁', '45岁以上']
# [6205455, 9612491, 2213612, 362400, 66849, 14663]

# %%
def bar_chart_age(x, y) -> Bar:
    background_color_js = (
        "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
        "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
    )
    c = (
        Bar(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
        #Bar()
        .add_xaxis(x)
        # .add_xaxis(searchcount.index.tolist()[:10])
        # .reversal_axis()
        .add_yaxis("", y, 
                   label_opts=opts.LabelOpts(position='inside', formatter="{c}"),
                  color='plum', category_gap="60%"
                  )
        .set_global_opts(xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-30, formatter="{value}"),
                                                 axisline_opts=opts.AxisLineOpts(is_show=False),),
                        yaxis_opts=opts.AxisOpts(
                            axislabel_opts=opts.LabelOpts(is_show=True),
                        axisline_opts=opts.AxisLineOpts(is_show=False),
                        axistick_opts=opts.AxisTickOpts(
                        is_show=True,
                        length=25,
                        linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
                    ),)
                        )
        .set_series_opts(
            itemstyle_opts={
            "normal": {
                "color": JsCode("""new echarts.graphic.LinearGradient(0, 0, 0, 1, [{
                    offset: 0,
                    color: 'rgba(255,100,97,.5)'
                }, {
                    offset: 1,
                    color: 'rgba(221,160,221)'
                }], false)"""),
                "barBorderRadius": [30, 30, 30, 30],
                "shadowColor": 'rgb(0, 160, 221)',
            }}
        )
    )
    return c

# %%
bar_chart_age(statics_x, statics_y).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c49d4771f1b84c6787a72f222cffdea4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c49d4771f1b84c6787a72f222cffdea4 = echarts.init(
#                     document.getElementById('c49d4771f1b84c6787a72f222cffdea4'), 'white', {renderer: 'canvas'});
#                 var option_c49d4771f1b84c6787a72f222cffdea4 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "plum",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 6205455,
#                 9612491,
#                 2213612,
#                 362400,
#                 66849,
#                 14663
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "60%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "formatter": "{c}"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{                    offset: 0,                    color: 'rgba(255,100,97,.5)'                }, {                    offset: 1,                    color: 'rgba(221,160,221)'                }], false),
#                     "barBorderRadius": [
#                         30,
#                         30,
#                         30,
#                         30
#                     ],
#                     "shadowColor": "rgb(0, 160, 221)"
#                 }
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": -30,
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "24\u5c81\u4ee5\u4e0b",
#                 "25\u5c81-29\u5c81",
#                 "30\u5c81-34\u5c81",
#                 "35\u5c81-39\u5c81",
#                 "40\u5c81-44\u5c81",
#                 "45\u5c81\u4ee5\u4e0a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c49d4771f1b84c6787a72f222cffdea4.setOption(option_c49d4771f1b84c6787a72f222cffdea4);
#         });
#     </script>

# %% [markdown]
# #### 月度平均薪资 - 折线图

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByMonth']:
    statics_x.append(i['year'] + '-' + i['month'])
    statics_y.append(i['monthAveSalary'])
print(statics_x)
print(statics_y)
# Out:
# ['2020年-2月', '2020年-3月', '2020年-4月', '2020年-5月', '2020年-6月', '2020年-7月', '2020年-8月', '2020年-9月', '2020年-10月', '2020年-11月', '2020年-12月', '2021年-1月']
# [8852, 8433, 8338, 8253, 8311, 8266, 8443, 8480, 8497, 8627, 8765, 9104]

# %%
x_data = statics_x
y_data = statics_y

background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
area_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)"
)

c_line_month = (
    Line(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="薪资",
        y_axis=y_data,
        is_smooth=True,
        is_symbol_show=True,
        symbol="circle",
        symbol_size=6,
        linestyle_opts=opts.LineStyleOpts(color="#fff"),
        label_opts=opts.LabelOpts(is_show=True, position="top", color="white"),
        itemstyle_opts=opts.ItemStyleOpts(
            color="red", border_color="#fff", border_width=3
        ),
        tooltip_opts=opts.TooltipOpts(is_show=False),
        areastyle_opts=opts.AreaStyleOpts(color=JsCode(area_color_js), opacity=1),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="薪资变化",
            pos_bottom="5%",
            pos_left="center",
            title_textstyle_opts=opts.TextStyleOpts(color="#fff", font_size=16),
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            boundary_gap=False,
            axislabel_opts=opts.LabelOpts(rotate=-20, margin=30, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(is_show=False),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=25,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        yaxis_opts=opts.AxisOpts(
            min_=7500,
            type_="value",
            position="right",
            axislabel_opts=opts.LabelOpts(margin=20, color="#ffffff63"),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(width=2, color="#fff")
            ),
            axistick_opts=opts.AxisTickOpts(
                is_show=True,
                length=15,
                linestyle_opts=opts.LineStyleOpts(color="#ffffff1f"),
            ),
            splitline_opts=opts.SplitLineOpts(
                is_show=True, linestyle_opts=opts.LineStyleOpts(color="#ffffff1f")
            ),
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
)

# %%
c_line_month.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="30133ce6cdcc46f5a5115efccac4b861" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_30133ce6cdcc46f5a5115efccac4b861 = echarts.init(
#                     document.getElementById('30133ce6cdcc46f5a5115efccac4b861'), 'white', {renderer: 'canvas'});
#                 var option_30133ce6cdcc46f5a5115efccac4b861 = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u85aa\u8d44",
#             "connectNulls": false,
#             "symbol": "circle",
#             "symbolSize": 6,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020\u5e74-2\u6708",
#                     8852
#                 ],
#                 [
#                     "2020\u5e74-3\u6708",
#                     8433
#                 ],
#                 [
#                     "2020\u5e74-4\u6708",
#                     8338
#                 ],
#                 [
#                     "2020\u5e74-5\u6708",
#                     8253
#                 ],
#                 [
#                     "2020\u5e74-6\u6708",
#                     8311
#                 ],
#                 [
#                     "2020\u5e74-7\u6708",
#                     8266
#                 ],
#                 [
#                     "2020\u5e74-8\u6708",
#                     8443
#                 ],
#                 [
#                     "2020\u5e74-9\u6708",
#                     8480
#                 ],
#                 [
#                     "2020\u5e74-10\u6708",
#                     8497
#                 ],
#                 [
#                     "2020\u5e74-11\u6708",
#                     8627
#                 ],
#                 [
#                     "2020\u5e74-12\u6708",
#                     8765
#                 ],
#                 [
#                     "2021\u5e74-1\u6708",
#                     9104
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "white",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "#fff"
#             },
#             "areaStyle": {
#                 "opacity": 1,
#                 "color": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#eb64fb'}, {offset: 1, color: '#3fbbff0d'}], false)
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "itemStyle": {
#                 "color": "red",
#                 "borderColor": "#fff",
#                 "borderWidth": 3
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u85aa\u8d44": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": false,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 25,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "#ffffff63",
#                 "rotate": -20,
#                 "margin": 30
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "boundaryGap": false,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#ffffff1f"
#                 }
#             },
#             "data": [
#                 "2020\u5e74-2\u6708",
#                 "2020\u5e74-3\u6708",
#                 "2020\u5e74-4\u6708",
#                 "2020\u5e74-5\u6708",
#                 "2020\u5e74-6\u6708",
#                 "2020\u5e74-7\u6708",
#                 "2020\u5e74-8\u6708",
#                 "2020\u5e74-9\u6708",
#                 "2020\u5e74-10\u6708",
#                 "2020\u5e74-11\u6708",
#                 "2020\u5e74-12\u6708",
#                 "2021\u5e74-1\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 2,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": "#fff"
#                 }
#             },
#             "axisTick": {
#                 "show": true,
#                 "alignWithLabel": false,
#                 "inside": false,
#                 "length": 15,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,

# %% [markdown]
# #### 城市平均薪资 - 地图

# %%
from pyecharts.charts import Map
from pyecharts.faker import Faker

# %%
statics_x = []
statics_y = []
for i in job_statics_data_json['zpData']['salaryByCity']:
    if i['cityList']:
        statics_x.append(i['cityList'][0]['cityAveMonthSalary'])
    statics_y.append(i['provinceName'])

# %%
background_color_js = (
    "new echarts.graphic.LinearGradient(0, 0, 0, 1, "
    "[{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false)"
)
c = (
    Map(init_opts=opts.InitOpts(bg_color=JsCode(background_color_js)))
    .add("全国薪资", [list(z) for z in zip(statics_y, statics_x)], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title=""),
        visualmap_opts=opts.VisualMapOpts(max_=15000, min_=6000),
    )
)

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="0913ee83eafa421e9f017e83373a14ca" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_0913ee83eafa421e9f017e83373a14ca = echarts.init(
#                     document.getElementById('0913ee83eafa421e9f017e83373a14ca'), 'white', {renderer: 'canvas'});
#                 var option_0913ee83eafa421e9f017e83373a14ca = {
#     "backgroundColor": new echarts.graphic.LinearGradient(0, 0, 0, 1, [{offset: 0, color: '#c86589'}, {offset: 1, color: '#06a7ff'}], false),
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5168\u56fd\u85aa\u8d44",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 15244
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 14419
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 8950
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 8629
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 6303
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 6893
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 6740
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 6730
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 6755
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 9715
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 7622
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 6830
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 7923
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 11069
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 10076
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 13234
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 8644
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 7916
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 7275
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 9067
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 7471
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 9932
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 10392
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 7478
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 6695
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 7666
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5168\u56fd\u85aa\u8d44"
#             ],
#             "selected": {
#                 "\u5168\u56fd\u85aa\u8d44": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 6000,
#         "max": 15000,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_0913ee83eafa421e9f017e83373a14ca.setOption(option_0913ee83eafa421e9f017e83373a14ca);
#         });
#     </script>
